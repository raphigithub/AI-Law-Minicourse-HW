# %%
embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1618b6ea0540> in <module>()
# ----> 1 embeddings = tf.Variable(
#       2     tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
#
# NameError: name 'tf' is not defined

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\programdata\anaconda3\lib\site-packages
# Requirement already satisfied: tensorflow-tensorboard<0.5.0,>=0.4.0rc1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: protobuf>=3.3.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: numpy>=1.12.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: enum34>=1.1.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: werkzeug>=0.11.10 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)
# Collecting bleach==1.5.0 (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)
# Exception:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\basecommand.py", line 215, in main
#     status = self.run(options, args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\commands\install.py", line 335, in run
#     wb.build(autobuilding=True)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\wheel.py", line 749, in build
#     self.requirement_set.prepare_files(self.finder)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\req\req_set.py", line 380, in prepare_files
#     ignore_dependencies=self.ignore_dependencies))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\req\req_set.py", line 554, in _prepare_file
#     require_hashes
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\req\req_install.py", line 278, in populate_link
#     self.link = finder.find_requirement(self, upgrade)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\index.py", line 465, in find_requirement
#     all_candidates = self.find_all_candidates(req.name)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\index.py", line 423, in find_all_candidates
#     for page in self._get_pages(url_locations, project_name):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\index.py", line 568, in _get_pages
#     page = self._get_page(location)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\index.py", line 683, in _get_page
#     return HTMLPage.get_page(link, session=self.session)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\index.py", line 811, in get_page
#     inst = cls(resp.content, resp.url, resp.headers)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\index.py", line 731, in __init__
#     namespaceHTMLElements=False,
# TypeError: parse() got an unexpected keyword argument 'transport_encoding'

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of
# Initialized
# Average loss at step  0 :  310.7364501953125
# Nearest to known: regan, conspirator, omitting, goodyear, nunavut, molly, kanagawa, domain,
# Nearest to of: promotional, nagasaki, fearsome, freedmen, machines, strength, tbs, bacchus,
# Nearest to will: heller, tigris, snap, pursuit, gael, dissected, theistic, ladislaus,
# Nearest to use: bathe, owner, communicated, brownish, birthplace, ortega, andromache, bah,
# Nearest to a: witte, toughness, tonk, dissipate, polka, commandants, tuition, aphelion,
# Nearest to than: height, organisations, hamadan, one, marquette, frederic, amway, bootable,
# Nearest to and: callixtus, bursting, averroes, monotonous, dxm, schala, ravages, jer,
# Nearest to new: alarc, unionists, alchemist, spices, dq, caribou, harshness, watercraft,
# Nearest to no: kwakiutl, refer, persecute, thereabouts, langle, tornado, sunsets, slovene,
# Nearest to other: film, havre, deluded, curving, sayer, nio, nther, likelihood,
# Nearest to years: fished, angora, tetrachloride, disneyland, freebsd, marischal, irritability, talmadge,
# Nearest to seven: rum, metro, gunship, toys, commissioning, flatland, involuntarily, consilience,
# Nearest to world: harass, reveals, squaw, asser, ambulance, vietnamese, destroying, metroid,
# Nearest to during: attendants, comeback, loy, brothel, ops, gagauz, bisexuals, piled,
# Nearest to that: plekhanov, barrows, validated, mend, appended, sic, hygienic, raison,
# Nearest to these: voter, casein, olympia, ancestry, conservatorium, mcduck, dorothea, yosemite,
# Average loss at step  2000 :  112.89808523273469
# Average loss at step  4000 :  53.12795196866989
# Average loss at step  6000 :  33.23646133732796
# Average loss at step  8000 :  23.866267781376838
# Average loss at step  10000 :  17.747401577472687
# Nearest to known: regan, challenge, domain, nunavut, agave, disturbed, sydney, years,
# Nearest to of: and, in, for, after, nine, the, from, reading,
# Nearest to will: snap, pursuit, outline, supporting, included, thebes, theistic, resulted,
# Nearest to use: owner, receiving, sketching, basins, birthplace, records, namely, phi,
# Nearest to a: the, archie, and, one, UNK, which, his, their,
# Nearest to than: height, hamadan, organisations, still, gland, lectures, save, and,
# Nearest to and: of, in, UNK, the, to, or, agave, archie,
# Nearest to new: alchemist, mya, biscuit, unionists, gland, satisfaction, omnibus, novelist,
# Nearest to no: refer, ngc, science, tornado, okavango, and, cc, that,
# Nearest to other: film, aikido, archie, examination, computing, stop, ambients, developments,
# Nearest to years: agave, bodyline, disneyland, honorary, statements, known, zero, angora,
# Nearest to seven: zero, nine, lymphoma, dreyfus, gb, omnibus, one, three,
# Nearest to world: three, destroying, purchased, vietnamese, receiving, reveals, vs, scholars,
# Nearest to during: comeback, gland, attendants, attached, autonomy, layers, from, succumbed,
# Nearest to that: which, and, validated, aries, sic, tides, electronic, netherlands,
# Nearest to these: mya, ignosticism, fans, cm, ancestry, weekly, allah, izmir,
# Average loss at step  12000 :  14.135806134700776
# Average loss at step  14000 :  11.730394037485123
# Average loss at step  16000 :  9.868942471861839
# Average loss at step  18000 :  8.574171888291836
# Average loss at step  20000 :  8.081728222489357
# Nearest to known: challenge, disturbed, regan, nunavut, macedonia, sydney, agave, unix,
# Nearest to of: in, and, for, nine, dasyprocta, eight, from, circ,
# Nearest to will: snap, dasyprocta, nasdaq, pursuit, outline, aj, thebes, discusses,
# Nearest to use: owner, birthplace, receiving, sketching, abort, dye, communicated, basins,
# Nearest to a: the, agouti, his, dasyprocta, their, one, UNK, part,
# Nearest to than: height, hamadan, organisations, and, still, or, lectures, gland,
# Nearest to and: or, dasyprocta, agouti, in, of, for, zero, circ,
# Nearest to new: alchemist, mya, biscuit, unionists, menus, ephraem, judas, harshness,
# Nearest to no: refer, ngc, science, okavango, and, that, agouti, tornado,
# Nearest to other: aikido, archie, film, examination, agouti, ambients, these, stop,
# Nearest to years: agave, gnat, nine, disneyland, five, bodyline, four, days,
# Nearest to seven: nine, eight, zero, three, six, four, five, one,
# Nearest to world: asser, destroying, purchased, vietnamese, three, jacobite, receiving, reveals,
# Nearest to during: attendants, from, in, comeback, by, into, gland, dasyprocta,
# Nearest to that: which, circ, but, agouti, and, dasyprocta, netherlands, sic,
# Nearest to these: voter, agouti, other, ignosticism, the, mya, dorothea, asymmetrical,
# Average loss at step  22000 :  7.09004367184639
# Average loss at step  24000 :  6.810192885637283
# Average loss at step  26000 :  6.743487408220768
# Average loss at step  28000 :  6.3924945797920225
# Average loss at step  30000 :  5.924214516758918
# Nearest to known: omitting, disturbed, challenge, regan, nunavut, agave, but, macedonia,
# Nearest to of: in, and, for, eight, dasyprocta, main, nine, from,
# Nearest to will: would, snap, could, nasdaq, dasyprocta, aj, included, swapped,
# Nearest to use: birthplace, owner, sketching, receiving, ortega, communicated, wheatstone, namely,
# Nearest to a: the, agouti, dasyprocta, this, their, or, operatorname, archie,
# Nearest to than: and, or, organisations, hamadan, height, still, granddaughter, skeptical,
# Nearest to and: or, agouti, dasyprocta, in, but, amalthea, for, circ,
# Nearest to new: alchemist, mya, menus, harshness, azad, biscuit, unionists, judas,
# Nearest to no: ngc, refer, okavango, inoue, science, they, angled, sixteenth,
# Nearest to other: these, archie, aikido, examination, agouti, lc, ambients, causation,
# Nearest to years: sponsors, four, gnat, agave, disneyland, five, bodyline, two,
# Nearest to seven: eight, nine, four, five, six, three, zero, dasyprocta,
# Nearest to world: purchased, jacobite, asser, destroying, vietnamese, reveals, receiving, augustus,
# Nearest to during: in, from, attendants, by, into, since, and, comeback,
# Nearest to that: which, but, this, agouti, circ, dasyprocta, it, tides,
# Nearest to these: voter, many, other, agouti, which, all, ignosticism, mya,
# Average loss at step  32000 :  5.978863420367241
# Average loss at step  34000 :  5.719595029592514
# Average loss at step  36000 :  5.766357278823852
# Average loss at step  38000 :  5.515861285805702
# Average loss at step  40000 :  5.297067711114884
# Nearest to known: disturbed, omitting, regan, challenge, but, nunavut, unix, conspirator,
# Nearest to of: in, zero, dasyprocta, nine, for, and, main, from,
# Nearest to will: would, could, can, snap, to, dasyprocta, included, nasdaq,
# Nearest to use: birthplace, owner, sketching, ortega, receiving, wheatstone, dasyprocta, communicated,
# Nearest to a: the, agouti, dasyprocta, this, zero, operatorname, their, one,
# Nearest to than: or, organisations, hamadan, and, height, for, liddell, zero,
# Nearest to and: or, zero, agouti, but, dasyprocta, in, circ, amalthea,
# Nearest to new: alchemist, mya, menus, harshness, azad, unionists, gutenberg, omnibus,
# Nearest to no: ngc, refer, inoue, okavango, federline, sixteenth, that, ardennes,
# Nearest to other: these, archie, aikido, agouti, examination, causation, handicap, lc,
# Nearest to years: four, sponsors, six, five, three, gnat, days, disneyland,
# Nearest to seven: eight, zero, six, four, nine, three, five, two,
# Nearest to world: harass, jacobite, metroid, purchased, asser, vietnamese, destroying, reveals,
# Nearest to during: in, from, and, since, on, attendants, into, pickle,
# Nearest to that: which, but, this, agouti, circ, dasyprocta, it, while,
# Nearest to these: many, voter, some, other, all, mcduck, which, agouti,
# Average loss at step  42000 :  5.3717798299789425
# Average loss at step  44000 :  5.220209018468857
# Average loss at step  46000 :  5.225632820129395
# Average loss at step  48000 :  5.232476683616638
# Average loss at step  50000 :  4.9659680839777
# Nearest to known: omitting, disturbed, regan, challenge, but, nunavut, conspirator, unix,
# Nearest to of: in, for, nine, dasyprocta, eight, yoannis, six, main,
# Nearest to will: would, could, can, to, must, may, dasyprocta, should,
# Nearest to use: birthplace, sketching, ortega, dasyprocta, receiving, owner, form, ajmer,
# Nearest to a: the, this, agouti, dasyprocta, governorates, or, eight, their,
# Nearest to than: or, and, organisations, hamadan, for, skeptical, roller, gch,
# Nearest to and: or, but, agouti, four, six, five, dasyprocta, seven,
# Nearest to new: alchemist, azad, menus, mya, unionists, harshness, omnibus, synth,
# Nearest to no: ngc, refer, inoue, okavango, federline, there, sixteenth, dumb,
# Nearest to other: these, handicap, archie, causation, kapoor, agouti, many, examination,
# Nearest to years: four, days, disneyland, sponsors, gnat, bodyline, five, six,
# Nearest to seven: eight, six, three, four, five, nine, zero, one,
# Nearest to world: harass, jacobite, purchased, metroid, asser, vietnamese, destroying, touchdowns,
# Nearest to during: in, from, since, on, pickle, of, into, yoannis,
# Nearest to that: which, this, but, circ, it, agouti, dasyprocta, about,
# Nearest to these: many, some, other, all, voter, which, mcduck, agouti,
# Average loss at step  52000 :  5.039325838804245
# Average loss at step  54000 :  5.190067229866981
# Average loss at step  56000 :  5.046791471481323
# Average loss at step  58000 :  5.053505633950233
# Average loss at step  60000 :  4.943846652626991
# Nearest to known: disturbed, omitting, such, regan, but, intersecting, challenge, nunavut,
# Nearest to of: in, ursus, and, for, nine, dasyprocta, including, kapoor,
# Nearest to will: would, could, can, may, heller, must, to, should,
# Nearest to use: birthplace, form, ortega, sketching, dasyprocta, owner, ajmer, dye,
# Nearest to a: michelob, the, agouti, this, dasyprocta, ursus, coke, any,
# Nearest to than: or, organisations, hamadan, skeptical, but, gch, and, roller,
# Nearest to and: or, ursus, but, agouti, dasyprocta, wct, in, johansen,
# Nearest to new: alchemist, azad, wct, menus, mya, harshness, unionists, omnibus,
# Nearest to no: ngc, inoue, sixteenth, federline, okavango, there, refer, dumb,
# Nearest to other: these, wct, many, archie, agouti, causation, some, handicap,
# Nearest to years: days, four, six, five, disneyland, sponsors, bodyline, gnat,
# Nearest to seven: eight, six, five, nine, four, three, zero, michelob,
# Nearest to world: jacobite, harass, purchased, michelob, asser, metroid, destroying, vietnamese,
# Nearest to during: in, from, since, on, pickle, yoannis, and, of,
# Nearest to that: which, but, this, circ, wct, ursus, about, however,
# Nearest to these: many, some, other, all, wct, voter, which, are,
# Average loss at step  62000 :  5.000118705511093
# Average loss at step  64000 :  4.843994465470314
# Average loss at step  66000 :  4.595182622671127
# Average loss at step  68000 :  4.975296969175338
# Average loss at step  70000 :  4.913808867096901
# Nearest to known: disturbed, omitting, such, intersecting, regan, described, but, used,
# Nearest to of: microcebus, ursus, dasyprocta, and, in, michelob, nine, wct,
# Nearest to will: would, can, could, may, must, should, to, heller,
# Nearest to use: form, birthplace, ortega, tamarin, dasyprocta, sketching, soroban, transit,
# Nearest to a: the, michelob, mico, agouti, any, cebus, dasyprocta, this,
# Nearest to than: or, organisations, and, skeptical, gch, hamadan, roller, but,
# Nearest to and: or, but, ursus, thaler, agouti, callithrix, dasyprocta, wct,
# Nearest to new: wct, alchemist, azad, harshness, menus, mya, mukherjee, unionists,
# Nearest to no: ngc, inoue, federline, sixteenth, refer, there, dumb, okavango,
# Nearest to other: these, many, wct, different, some, handicap, archie, agouti,
# Nearest to years: days, four, six, five, disneyland, months, callithrix, bodyline,
# Nearest to seven: eight, six, five, four, nine, three, zero, michelob,
# Nearest to world: jacobite, harass, purchased, asser, michelob, dist, cebus, destroying,
# Nearest to during: in, from, since, pickle, thaler, on, yoannis, amalthea,
# Nearest to that: which, this, but, wct, about, circ, ursus, however,
# Nearest to these: many, some, all, other, which, wct, they, voter,
# Average loss at step  72000 :  4.750965384840965
# Average loss at step  74000 :  4.794808797478676
# Average loss at step  76000 :  4.734263729572296
# Average loss at step  78000 :  4.815841780781746
# Average loss at step  80000 :  4.807932691037655
# Nearest to known: disturbed, such, omitting, used, described, intersecting, defined, regan,
# Nearest to of: iit, dasyprocta, ursus, in, kapoor, microcebus, recitative, nine,
# Nearest to will: would, can, could, may, must, should, to, heller,
# Nearest to use: form, birthplace, ortega, tamarin, sketching, dasyprocta, transit, publicized,
# Nearest to a: the, michelob, mico, agouti, dasyprocta, cebus, coke, ursus,
# Nearest to than: or, and, skeptical, organisations, gch, ec, roller, but,
# Nearest to and: or, but, ursus, callithrix, agouti, thaler, dasyprocta, wct,
# Nearest to new: wct, alchemist, mukherjee, azad, mya, menus, harshness, omnibus,
# Nearest to no: ngc, inoue, there, refer, federline, verge, okavango, sixteenth,
# Nearest to other: these, many, different, wct, some, causation, agouti, handicap,
# Nearest to years: days, months, four, disneyland, callithrix, six, gnat, bodyline,
# Nearest to seven: eight, six, four, five, nine, three, one, zero,
# Nearest to world: harass, jacobite, purchased, asser, michelob, squaw, dist, cebus,
# Nearest to during: in, from, since, pickle, thaler, by, amalthea, of,
# Nearest to that: which, this, but, however, wct, circ, ursus, agouti,
# Nearest to these: many, some, all, other, which, such, several, they,
# Average loss at step  82000 :  4.768187309384346
# Average loss at step  84000 :  4.75480662047863
# Average loss at step  86000 :  4.760735605478287
# Average loss at step  88000 :  4.755839492797851
# Average loss at step  90000 :  4.725417955636978
# Nearest to known: used, disturbed, described, such, omitting, defined, intersecting, agave,
# Nearest to of: ursus, microcebus, dasyprocta, iit, in, nine, including, domingue,
# Nearest to will: would, can, could, may, must, should, to, might,
# Nearest to use: form, birthplace, dasyprocta, ortega, tamarin, sketching, callithrix, course,
# Nearest to a: the, michelob, agouti, mico, this, cebus, another, any,
# Nearest to than: or, gch, skeptical, organisations, and, but, roller, ec,
# Nearest to and: or, but, ursus, while, thaler, callithrix, agouti, dasyprocta,
# Nearest to new: wct, mukherjee, mya, azad, omnibus, alchemist, modern, chalukyas,
# Nearest to no: ngc, federline, inoue, any, shen, there, agouti, refer,
# Nearest to other: these, different, some, wct, many, agouti, handicap, ursus,
# Nearest to years: days, months, hours, disneyland, bodyline, gnat, six, callithrix,
# Nearest to seven: eight, six, five, four, nine, three, zero, michelob,
# Nearest to world: harass, purchased, jacobite, asser, squaw, michelob, dist, touchdowns,
# Nearest to during: in, from, since, pickle, thaler, on, under, by,
# Nearest to that: which, but, this, however, ursus, peacocks, circ, wct,
# Nearest to these: many, some, all, such, which, other, several, they,
# Average loss at step  92000 :  4.662079968571663
# Average loss at step  94000 :  4.722758465528488
# Average loss at step  96000 :  4.691315218925476
# Average loss at step  98000 :  4.580839628815651
# Average loss at step  100000 :  4.689781085371971
# Nearest to known: used, such, described, disturbed, defined, omitting, agave, intersecting,
# Nearest to of: iit, including, in, microcebus, ursus, recitative, dasyprocta, same,
# Nearest to will: would, can, could, may, must, should, might, included,
# Nearest to use: form, dasyprocta, birthplace, ortega, tamarin, callithrix, transit, thibetanus,
# Nearest to a: the, michelob, mico, agouti, any, constituci, cebus, dasyprocta,
# Nearest to than: or, gch, and, skeptical, organisations, roller, but, diefenbaker,
# Nearest to and: or, but, ursus, callithrix, thaler, while, agouti, johansen,
# Nearest to new: wct, modern, alchemist, mukherjee, mya, azad, menus, omnibus,
# Nearest to no: ngc, any, federline, inoue, shen, agouti, there, sixteenth,
# Nearest to other: different, these, some, wct, many, causation, handicap, various,
# Nearest to years: days, months, hours, disneyland, bodyline, gnat, haiti, six,
# Nearest to seven: eight, six, five, four, nine, three, zero, michelob,
# Nearest to world: harass, purchased, jacobite, asser, squaw, michelob, dist, cebus,
# Nearest to during: in, since, from, pickle, after, thaler, under, until,
# Nearest to that: which, this, however, but, wct, circ, ursus, agouti,
# Nearest to these: many, some, such, all, which, several, they, other,
